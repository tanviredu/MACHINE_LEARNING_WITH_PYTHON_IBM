# %% [markdown]
# #### h2o is just like a framework for the machine learning with the underlying java based program. the most imporant thing is you dont need multiple packages from multiple sources . one packages will provide you all

# %%
## first install the h2o packages
# !pip install h2o

# %%
## then initialize the h2o server in the jupyter notebook
import h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O cluster uptime:         21 mins 04 secs
# H2O cluster timezone:       Etc/UTC
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.28.0.3
# H2O cluster version age:    23 days
# H2O cluster name:           H2O_from_python_unknownUser_hhc8ty
# H2O cluster total nodes:    1
# H2O cluster free memory:    3 Gb
# H2O cluster total cores:    2
# H2O cluster allowed cores:  2
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:       {'http': None, 'https': None}
# H2O internal security:      False
# H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python version:             3.6.9 final
# ...

# %% [markdown]
# ### now we import a data set and run a test deep learning for testing ourpose

# %%
## we store in the variable called df .df stands for dataframe
data_url = "https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv"

# %%
df = h2o.import_file(data_url)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
## lets see the data
df
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  sepal.length</th><th style="text-align: right;">  sepal.width</th><th style="text-align: right;">  petal.length</th><th style="text-align: right;">  petal.width</th><th>variety  </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">           5.1</td><td style="text-align: right;">          3.5</td><td style="text-align: right;">           1.4</td><td style="text-align: right;">          0.2</td><td>Setosa   </td></tr>
# <tr><td style="text-align: right;">           4.9</td><td style="text-align: right;">          3  </td><td style="text-align: right;">           1.4</td><td style="text-align: right;">          0.2</td><td>Setosa   </td></tr>
# <tr><td style="text-align: right;">           4.7</td><td style="text-align: right;">          3.2</td><td style="text-align: right;">           1.3</td><td style="text-align: right;">          0.2</td><td>Setosa   </td></tr>
# ...

# %%
## if you want you can convert the data in pandas dataframe any time
df.as_data_frame().corr().plot()
