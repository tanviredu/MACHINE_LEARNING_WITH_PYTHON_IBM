# %%
# !pip install h2o
# Out:
# ...
#      |████████████████████████████████| 123.6MB 139kB/s
# ...
#   Created wheel for h2o: filename=h2o-3.26.0.5-py2.py3-none-any.whl size=123672284 sha256=892cb4406ec0cf846f1e8cba30e48cd80a31852cfdbbf2053e08fbda4a939b4e
#   Stored in directory: /root/.cache/pip/wheels/c9/d2/24/eeb5f07ff6826ea23325338cd3fb5754b99592a3f2b4e67f27
# Successfully built h2o
# ...
